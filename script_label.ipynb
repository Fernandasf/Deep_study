# %%
#Exemplo Tiago
f = open('label.csv', 'w')

for revE in range(10):
    for hfdE in range(10):
        filename = "academia_" + str(revE*10) + "_" + str(hfdE*10) + ".wav ACADEMIA\n"
        f.write(filename)

f.close()

# %%
#script para gerar os labels com reverberação



#limpas
f = open('fernanda_audios/label.txt', 'w')

for a in range(1,401):
    filename = "academia" + str(a) + ".wav ACADEMIA\n"
    f.write(filename)
for l in range(1,401):
    filename15 = "aeroporto" + str(l) + ".wav AEROPORTO\n"
    f.write(filename15)
for v in range(1,401):
    filename29 = "casa" + str(v) + ".wav CASA\n"
    f.write(filename29)    
for ag in range(1,401):
    filename43 = "cinema" + str(ag) + ".wav CINEMA\n"
    f.write(filename43)
for aq in range(1,401):
    filename57 = "escola" + str(aq) + ".wav ESCOLA\n"
    f.write(filename57)
for aac in range(1,401):
    filename71 = "faculdade" + str(aac) + ".wav FACULDADE\n"
    f.write(filename71)
for aam in range(1,401):
    filename85 = "farmacia" + str(aam) + ".wav FARMACIA\n"
    f.write(filename85)
for aaw in range(1,401):
    filename99 = "hospital" + str(aaw) + ".wav HOSPITAL\n"
    f.write(filename99)
for aaah in range(1,401):
    filename113 = "mercado" + str(aaah) + ".wav MERCADO\n"
    f.write(filename113)
for aaar in range(1,401):
    filename127 = "trabalho" + str(aaar) + ".wav TRABALHO\n"
    f.write(filename127)
f.close()
""" 


#reverb com 10%  
f = open('fernanda_noise_norm/noise_10/label_noise_10.txt', 'w')

for a in range(1,401):
    filename = "academia" + str(a) + "_10.wav ACADEMIA\n"
    f.write(filename)
for l in range(1,401):
    filename15 = "aeroporto" + str(l) + "_10.wav AEROPORTO\n"
    f.write(filename15)
for v in range(1,401):
    filename29 = "casa" + str(v) + "_10.wav CASA\n"
    f.write(filename29)    
for ag in range(1,401):
    filename43 = "cinema" + str(ag) + "_10.wav CINEMA\n"
    f.write(filename43)
for aq in range(1,401):
    filename57 = "escola" + str(aq) + "_10.wav ESCOLA\n"
    f.write(filename57)
for aac in range(1,401):
    filename71 = "faculdade" + str(aac) + "_10.wav FACULDADE\n"
    f.write(filename71)
for aam in range(1,401):
    filename85 = "farmacia" + str(aam) + "_10.wav FARMACIA\n"
    f.write(filename85)
for aaw in range(1,401):
    filename99 = "hospital" + str(aaw) + "_10.wav HOSPITAL\n"
    f.write(filename99)
for aaah in range(1,401):
    filename113 = "mercado" + str(aaah) + "_10.wav MERCADO\n"
    f.write(filename113)
for aaar in range(1,401):
    filename127 = "trabalho" + str(aaar) + "_10.wav TRABALHO\n"
    f.write(filename127)
f.close()    

#Reverb com 20%
f = open('fernanda_noise_norm/noise_20/label_noise_20.txt', 'w')

for b in range(1,401):
    filename2 = "academia" + str(b) + "_20.wav ACADEMIA\n"
    f.write(filename2)
for m in range(1,401):
    filename16 = "aeroporto" + str(m) + "_20.wav AEROPORTO\n"
    f.write(filename16)
for w in range(1,401):
    filename30 = "casa" + str(w) + "_20.wav CASA\n"
    f.write(filename30)
for ah in range(1,401):
    filename44 = "cinema" + str(ah) + "_20.wav CINEMA\n"
    f.write(filename44)
for ar in range(1,401):
    filename58 = "escola" + str(ar) + "_20.wav ESCOLA\n"
    f.write(filename58)
for aad in range(1,401):
    filename72 = "faculdade" + str(aad) + "_20.wav FACULDADE\n"
    f.write(filename72)
for aan in range(1,401):
    filename86 = "farmacia" + str(aan) + "_20.wav FARMACIA\n"
    f.write(filename86)
for aax in range(1,401):
    filename100 = "hospital" + str(aax) + "_20.wav HOSPITAL\n"
    f.write(filename100)
for aaai in range(1,401):
    filename114 = "mercado" + str(aaai) + "_20.wav MERCADO\n"
    f.write(filename114)
for aaas in range(1,401):
    filename128 = "trabalho" + str(aaas) + "_20.wav TRABALHO\n"
    f.write(filename128)    
f.close()    
    
#Reverb com 30%
f = open('fernanda_noise_norm/noise_30/label_noise_30.txt', 'w')
    
for c in range(1,401):
    filename3 = "academia" + str(c) + "_30.wav ACADEMIA\n"
    f.write(filename3)
for n in range(1,401):
    filename17 = "aeroporto" + str(n) + "_30.wav AEROPORTO\n"
    f.write(filename17)
for x in range(1,401):
    filename31 = "casa" + str(x) + "_30.wav CASA\n"
    f.write(filename31)
for ai in range(1,401):
    filename45 = "cinema" + str(ai) + "_30.wav CINEMA\n"
    f.write(filename45)
for at in range(1,401):
    filename59 = "escola" + str(at) + "_30.wav ESCOLA\n"
    f.write(filename59)
for aae in range(1,401):
    filename73 = "faculdade" + str(aae) + "_30.wav FACULDADE\n"
    f.write(filename73)
for aao in range(1,401):
    filename87 = "farmacia" + str(aao) + "_30.wav FARMACIA\n"
    f.write(filename87)
for aaz in range(1,401):
    filename101 = "hospital" + str(aaz) + "_30.wav HOSPITAL\n"
    f.write(filename101)
for aaaj in range(1,401):
    filename115 = "mercado" + str(aaaj) + "_30.wav MERCADO\n"
    f.write(filename115)
for aaat in range(1,401):
    filename129 = "trabalho" + str(aaat) + "_30.wav TRABALHO\n"
    f.write(filename129)    
f.close()     

#Reverb com 40%
f = open('fernanda_noise_norm/noise_40/label_noise_40.txt', 'w')

for d in range(1,401):
    filename4 = "academia" + str(d) + "_40.wav ACADEMIA\n"
    f.write(filename4)
for o in range(1,401):
    filename18 = "aeroporto" + str(o) + "_40.wav AEROPORTO\n"
    f.write(filename18)
for z in range(1,401):
    filename32 = "casa" + str(z) + "_40.wav CASA\n"
    f.write(filename32)
for aj in range(1,401):
    filename46 = "cinema" + str(aj) + "_40.wav CINEMA\n"
    f.write(filename46)
for au in range(1,401):
    filename60 = "escola" + str(au) + "_40.wav ESCOLA\n"
    f.write(filename60)
for aaf in range(1,401):
    filename74 = "faculdade" + str(aaf) + "_40.wav FACULDADE\n"
    f.write(filename74)
for aap in range(1,401):
    filename88 = "farmacia" + str(aap) + "_40.wav FARMACIA\n"
    f.write(filename88)
for aaaa in range(1,401):
    filename102 = "hospital" + str(aaaa) + "_40.wav HOSPITAL\n"
    f.write(filename102)
for aaak in range(1,401):
    filename116 = "mercado" + str(aaak) + "_40.wav MERCADO\n"
    f.write(filename116)
for aaau in range(1,401):
    filename130 = "trabalho" + str(aaau) + "_40.wav TRABALHO\n"
    f.write(filename130)    
f.close()  

#Reverb com 50%
f = open('fernanda_noise_norm/noise_50/label_noise_50.txt', 'w')

for e in range(1,401):
    filename5 = "academia" + str(e) + "_50.wav ACADEMIA\n"
    f.write(filename5)
for p in range(1,401):
    filename19 = "aeroporto" + str(p) + "_50.wav AEROPORTO\n"
    f.write(filename19)
for aa in range(1,401):
    filename33 = "casa" + str(aa) + "_50.wav CASA\n"
    f.write(filename33)
for ak in range(1,401):
    filename47 = "cinema" + str(ak) + "_50.wav CINEMA\n"
    f.write(filename47)
for av in range(1,401):
    filename61 = "escola" + str(av) + "_50.wav ESCOLA\n"
    f.write(filename61)
for aag in range(1,401):
    filename75 = "faculdade" + str(aag) + "_50.wav FACULDADE\n"
    f.write(filename75)
for aaq in range(1,401):
    filename89 = "farmacia" + str(aaq) + "_50.wav FARMACIA\n"
    f.write(filename89)
for aaab in range(1,401):
    filename103 = "hospital" + str(aaab) + "_50.wav HOSPITAL\n"
    f.write(filename103)
for aaal in range(1,401):
    filename117 = "mercado" + str(aaal) + "_50.wav MERCADO\n"
    f.write(filename117)
for aaav in range(1,401):
    filename131 = "trabalho" + str(aaav) + "_50.wav TRABALHO\n"
    f.write(filename131)
f.close()  

#Reverb com 60%
f = open('fernanda_noise_norm/noise_60/label_noise_60.txt', 'w')

for g in range(1,401):
    filename6 = "academia" + str(g) + "_60.wav ACADEMIA\n"
    f.write(filename6)
for q in range(1,401):
    filename20 = "aeroporto" + str(q) + "_60.wav AEROPORTO\n"
    f.write(filename20)
for ab in range(1,401):
    filename34 = "casa" + str(ab) + "_60.wav CASA\n"
    f.write(filename34)
for al in range(1,401):
    filename48 = "cinema" + str(al) + "_60.wav CINEMA\n"
    f.write(filename48)
for ax in range(1,401):
    filename62 = "escola" + str(ax) + "_60.wav ESCOLA\n"
    f.write(filename62)
for aah in range(1,401):
    filename76 = "faculdade" + str(aah) + "_60.wav FACULDADE\n"
    f.write(filename76)
for aar in range(1,401):
    filename90 = "farmacia" + str(aar) + "_60.wav FARMACIA\n"
    f.write(filename90)
for aaac in range(1,401):
    filename104 = "hospital" + str(aaac) + "_60.wav HOSPITAL\n"
    f.write(filename104)
for aaam in range(1,401):
    filename118 = "mercado" + str(aaam) + "_60.wav MERCADO\n"
    f.write(filename118)
for aaaw in range(1,401):
    filename132 = "trabalho" + str(aaaw) + "_60.wav TRABALHO\n"
    f.write(filename132)   
f.close()  

#Reverb com 70%
f = open('fernanda_noise_norm/noise_70/label_noise_70.txt', 'w')

for h in range(1,401):
    filename7 = "academia" + str(h) + "_70.wav ACADEMIA\n"
    f.write(filename7)
for r in range(1,401):
    filename21 = "aeroporto" + str(r) + "_70.wav AEROPORTO\n"
    f.write(filename21)
for ac in range(1,401):
    filename35 = "casa" + str(ac) + "_70.wav CASA\n"
    f.write(filename35)
for am in range(1,401):
    filename49 = "cinema" + str(am) + "_70.wav CINEMA\n"
    f.write(filename49)
for aw in range(1,401):
    filename63 = "escola" + str(aw) + "_70.wav ESCOLA\n"
    f.write(filename63)
for aai in range(1,401):
    filename77 = "faculdade" + str(aai) + "_70.wav FACULDADE\n"
    f.write(filename77)
for aas in range(1,401):
    filename91 = "farmacia" + str(aas) + "_70.wav FARMACIA\n"
    f.write(filename91)
for aaad in range(1,401):
    filename105 = "hospital" + str(aaad) + "_70.wav HOSPITAL\n"
    f.write(filename105)
for aaan in range(1,401):
    filename119 = "mercado" + str(aaan) + "_70.wav MERCADO\n"
    f.write(filename119)
for aaax in range(1,401):
    filename133 = "trabalho" + str(aaax) + "_70.wav TRABALHO\n"
    f.write(filename133)  
f.close()  

#Reverb com 80%
f = open('fernanda_noise_norm/noise_80/label_noise_80.txt', 'w')

for i in range(1,401):
    filename8 = "academia" + str(i) + "_80.wav ACADEMIA\n"
    f.write(filename8)
for s in range(1,401):
    filename22 = "aeroporto" + str(s) + "_80.wav AEROPORTO\n"
    f.write(filename22)
for ad in range(1,401):
    filename36 = "casa" + str(ad) + "_80.wav CASA\n"
    f.write(filename36)
for an in range(1,401):
    filename50 = "cinema" + str(an) + "_80.wav CINEMA\n"
    f.write(filename50)
for az in range(1,401):
    filename64 = "escola" + str(az) + "_80.wav ESCOLA\n"
    f.write(filename64)
for aaj in range(1,401):
    filename78 = "faculdade" + str(aaj) + "_80.wav FACULDADE\n"
    f.write(filename78)
for aat in range(1,401):
    filename92 = "farmacia" + str(aat) + "_80.wav FARMACIA\n"
    f.write(filename92)
for aaae in range(1,401):
    filename106 = "hospital" + str(aaae) + "_80.wav HOSPITAL\n"
    f.write(filename106)
for aaao in range(1,401):
    filename120 = "mercado" + str(aaao) + "_80.wav MERCADO\n"
    f.write(filename120)
for aaaz in range(1,401):
    filename134 = "trabalho" + str(aaaz) + "_80.wav TRABALHO\n"
    f.write(filename134)
f.close()  

#Reverb com 90%
f = open('fernanda_noise_norm/noise_90/label_noise_90.txt', 'w')

for j in range(1,401):
    filename9 = "academia" + str(j) + "_90.wav ACADEMIA\n"
    f.write(filename9)
for t in range(1,401):
    filename23 = "aeroporto" + str(t) + "_90.wav AEROPORTO\n"
    f.write(filename23)
for ae in range(1,401):
    filename37 = "casa" + str(ae) + "_90.wav CASA\n"
    f.write(filename37)
for ao in range(1,401):
    filename51 = "cinema" + str(ao) + "_90.wav CINEMA\n"
    f.write(filename51)
for aaa in range(1,401):
    filename65 = "escola" + str(aaa) + "_90.wav ESCOLA\n"
    f.write(filename65)
for aak in range(1,401):
    filename79 = "faculdade" + str(aak) + "_90.wav FACULDADE\n"
    f.write(filename79)
for aau in range(1,401):
    filename93 = "farmacia" + str(aau) + "_90.wav FARMACIA\n"
    f.write(filename93)
for aaaf in range(1,401):
    filename107 = "hospital" + str(aaaf) + "_90.wav HOSPITAL\n"
    f.write(filename107)
for aaap in range(1,401):
    filename121 = "mercado" + str(aaap) + "_90.wav MERCADO\n"
    f.write(filename121)
for aaaaa in range(1,401):
    filename135 = "trabalho" + str(aaaaa) + "_90.wav TRABALHO\n"
    f.write(filename135)
f.close()  

#Reverb com 100%
f = open('fernanda_noise_norm/noise_100/label_noise_100.txt', 'w')
for k in range(1,401):
    filename10 = "academia" + str(k) + "_100.wav ACADEMIA\n"
    f.write(filename10)
for u in range(1,401):
    filename24 = "aeroporto" + str(u) + "_100.wav AEROPORTO\n"
    f.write(filename24)
for af in range(1,401):
    filename38 = "casa" + str(af) + "_100.wav CASA\n"
    f.write(filename38)
for ap in range(1,401):
    filename52 = "cinema" + str(ap) + "_100.wav CINEMA\n"
    f.write(filename52)
for aab in range(1,401):
    filename66 = "escola" + str(aab) + "_100.wav ESCOLA\n"
    f.write(filename66)
for aal in range(1,401):
    filename80 = "faculdade" + str(aal) + "_100.wav FACULDADE\n"
    f.write(filename80)
for aav in range(1,401):
    filename94 = "farmacia" + str(aav) + "_100.wav FARMACIA\n"
    f.write(filename94)
for aaag in range(1,401):
    filename108 = "hospital" + str(aaag) + "_100.wav HOSPITAL\n"
    f.write(filename108)
for aaaq in range(1,401):
    filename122 = "mercado" + str(aaaq) + "_100.wav MERCADO\n"
    f.write(filename122)
for aaaab in range(1,401):
    filename136 = "trabalho" + str(aaaab) + "_100.wav TRABALHO\n"
    f.write(filename136)
f.close() 



for rev in range(1,121):
    filename11 = "academia" + str(rev) + "_rev.wav ACADEMIA\n"
    f.write(filename11)
for hfd in range(1,121):
    filename12 = "academia" + str(hfd) + "_hfd.wav ACADEMIA\n"
    f.write(filename12)
for rsc in range(1,121):
    filename13 = "academia" + str(rsc) + "_rsc.wav ACADEMIA\n"
    f.write(filename13)
for pdl in range(1,121):
    filename14 = "academia" + str(pdl) + "_pdl.wav ACADEMIA\n"
    f.write(filename14)


for reva in range(1,121):
    filename25 = "aeroporto" + str(reva) + "_rev.wav AEROPORTO\n"
    f.write(filename25)
for hfda in range(1,121):
    filename26 = "aeroporto" + str(hfda) + "_hfd.wav AEROPORTO\n"
    f.write(filename26)
for rsca in range(1,121):
    filename27 = "aeroporto" + str(rsca) + "_rsc.wav AEROPORTO\n"
    f.write(filename27)
for pdla in range(1,121):
    filename28 = "aeroporto" + str(pdla) + "_pdl.wav AEROPORTO\n"
    f.write(filename28)


for revb in range(1,121):
    filename39 = "casa" + str(revb) + "_rev.wav CASA\n"
    f.write(filename39)
for hfdb in range(1,121):
    filename40 = "casa" + str(hfdb) + "_hfd.wav CASA\n"
    f.write(filename40)
for rscb in range(1,121):
    filename41 = "casa" + str(rscb) + "_rsc.wav CASA\n"
    f.write(filename41)
for pdlb in range(1,121):
    filename42 = "casa" + str(pdlb) + "_pdl.wav CASA\n"
    f.write(filename42)


for revc in range(1,121):
    filename53 = "cinema" + str(revc) + "_rev.wav CINEMA\n"
    f.write(filename53)
for hfdc in range(1,121):
    filename54 = "cinema" + str(hfdc) + "_hfd.wav CINEMA\n"
    f.write(filename54)
for rscc in range(1,121):
    filename55 = "cinema" + str(rscc) + "_rsc.wav CINEMA\n"
    f.write(filename55)
for pdlc in range(1,121):
    filename56 = "cinema" + str(pdlc) + "_pdl.wav CINEMA\n"
    f.write(filename56)


for revd in range(1,121):
    filename67 = "escola" + str(revd) + "_rev.wav ESCOLA\n"
    f.write(filename67)
for hfdd in range(1,121):
    filename68 = "escola" + str(hfdd) + "_hfd.wav ESCOLA\n"
    f.write(filename68)
for rscd in range(1,121):
    filename69 = "escola" + str(rscd) + "_rsc.wav ESCOLA\n"
    f.write(filename69)
for pdld in range(1,121):
    filename70 = "escola" + str(pdld) + "_pdl.wav ESCOLA\n"
    f.write(filename70)


for reve in range(1,121):
    filename81 = "faculdade" + str(reve) + "_rev.wav FACULDADE\n"
    f.write(filename81)
for hfde in range(1,121):
    filename82 = "faculdade" + str(hfde) + "_hfd.wav FACULDADE\n"
    f.write(filename82)
for rsce in range(1,121):
    filename83 = "faculdade" + str(rsce) + "_rsc.wav FACULDADE\n"
    f.write(filename83)
for pdle in range(1,121):
    filename84 = "faculdade" + str(pdle) + "_pdl.wav FACULDADE\n"
    f.write(filename84)


for revf in range(1,121):
    filename95 = "farmacia" + str(revf) + "_rev.wav FARMACIA\n"
    f.write(filename95)
for hfdf in range(1,121):
    filename96 = "farmacia" + str(hfdf) + "_hfd.wav FARMACIA\n"
    f.write(filename96)
for rscf in range(1,121):
    filename97 = "farmacia" + str(rscf) + "_rsc.wav FARMACIA\n"
    f.write(filename97)
for pdlf in range(1,121):
    filename98 = "farmacia" + str(pdlf) + "_pdl.wav FARMACIA\n"
    f.write(filename98)


for revg in range(1,121):
    filename109 = "hospital" + str(revg) + "_rev.wav HOSPITAL\n"
    f.write(filename109)
for hfdg in range(1,121):
    filename110 = "hospital" + str(hfdg) + "_hfd.wav HOSPITAL\n"
    f.write(filename110)
for rscg in range(1,121):
    filename111 = "hospital" + str(rscg) + "_rsc.wav HOSPITAL\n"
    f.write(filename111)
for pdlg in range(1,121):
    filename112 = "hospital" + str(pdlg) + "_pdl.wav HOSPITAL\n"
    f.write(filename112)


for revh in range(1,121):
    filename123 = "mercado" + str(revh) + "_rev.wav MERCADO\n"
    f.write(filename123)
for hfdh in range(1,121):
    filename124 = "mercado" + str(hfdh) + "_hfd.wav MERCADO\n"
    f.write(filename124)
for rsch in range(1,121):
    filename125 = "mercado" + str(rsch) + "_rsc.wav MERCADO\n"
    f.write(filename125)
for pdlh in range(1,121):
    filename126 = "mercado" + str(pdlh) + "_pdl.wav MERCADO\n"
    f.write(filename126)


for revj in range(1,121):
    filename137 = "trabalho" + str(revj) + "_rev.wav TRABALHO\n"
    f.write(filename137)
for hfdj in range(1,121):
    filename138 = "trabalho" + str(hfdj) + "_hfd.wav TRABALHO\n"
    f.write(filename138)
for rscj in range(1,121):
    filename139 = "trabalho" + str(rscj) + "_rsc.wav TRABALHO\n"
    f.write(filename139)
for pdlj in range(1,121):
    filename140 = "trabalho" + str(pdlj) + "_pdl.wav TRABALHO\n"
    f.write(filename140)
f.close()
"""
# Out:
# ' \n\n\n#reverb com 10%  \nf = open(\'fernanda_noise_norm/noise_10/label_noise_10.txt\', \'w\')\n\nfor a in range(1,401):\n    filename = "academia" + str(a) + "_10.wav ACADEMIA\n"\n    f.write(filename)\nfor l in range(1,401):\n    filename15 = "aeroporto" + str(l) + "_10.wav AEROPORTO\n"\n    f.write(filename15)\nfor v in range(1,401):\n    filename29 = "casa" + str(v) + "_10.wav CASA\n"\n    f.write(filename29)    \nfor ag in range(1,401):\n    filename43 = "cinema" + str(ag) + "_10.wav CINEMA\n"\n    f.write(filename43)\nfor aq in range(1,401):\n    filename57 = "escola" + str(aq) + "_10.wav ESCOLA\n"\n    f.write(filename57)\nfor aac in range(1,401):\n    filename71 = "faculdade" + str(aac) + "_10.wav FACULDADE\n"\n    f.write(filename71)\nfor aam in range(1,401):\n    filename85 = "farmacia" + str(aam) + "_10.wav FARMACIA\n"\n    f.write(filename85)\nfor aaw in range(1,401):\n    filename99 = "hospital" + str(aaw) + "_10.wav HOSPITAL\n"\n    f.write(filename99)\nfor aaah in ran
# ...

# %%
#script para gerar os labels na base limpa
f = open('labels_16800.txt', 'w')

for a in range(1,121):
    for b in range(1,15):
        filename = "academia" + str(a) + "_" + str(b) + ".wav ACADEMIA\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "aeroporto" + str(a) + "_" + str(b) + ".wav AEROPORTO\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "casa" + str(a) + "_" + str(b) + ".wav CASA\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "cinema" + str(a) + "_" + str(b) + ".wav CINEMA\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "escola" + str(a) + "_" + str(b) + ".wav ESCOLA\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "faculdade" + str(a) + "_" + str(b) + ".wav FACULDADE\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "farmacia" + str(a) + "_" + str(b) + ".wav FARMACIA\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "hospital" + str(a) + "_" + str(b) + ".wav HOSPITAL\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "mercado" + str(a) + "_" + str(b) + ".wav MERCADO\n"
        f.write(filename)
for a in range(1,121):
    for b in range(1,15):
        filename = "trabalho" + str(a) + "_" + str(b) + ".wav TRABALHO\n"
        f.write(filename)
#f.close()

# %%
#limpas
f = open('labels.txt', 'w')

for a in range(1,401):
    filename = "academia" + str(a) + ".wav ACADEMIA\n"
    f.write(filename)
for l in range(1,401):
    filename15 = "aeroporto" + str(l) + ".wav AEROPORTO\n"
    f.write(filename15)
for v in range(1,401):
    filename29 = "casa" + str(v) + ".wav CASA\n"
    f.write(filename29)    
for ag in range(1,401):
    filename43 = "cinema" + str(ag) + ".wav CINEMA\n"
    f.write(filename43)
for aq in range(1,401):
    filename57 = "escola" + str(aq) + ".wav ESCOLA\n"
    f.write(filename57)
for aac in range(1,401):
    filename71 = "faculdade" + str(aac) + ".wav FACULDADE\n"
    f.write(filename71)
for aam in range(1,401):
    filename85 = "farmacia" + str(aam) + ".wav FARMACIA\n"
    f.write(filename85)
for aaw in range(1,401):
    filename99 = "hospital" + str(aaw) + ".wav HOSPITAL\n"
    f.write(filename99)
for aaah in range(1,401):
    filename113 = "mercado" + str(aaah) + ".wav MERCADO\n"
    f.write(filename113)
for aaar in range(1,401):
    filename127 = "trabalho" + str(aaar) + ".wav TRABALHO\n"
    f.write(filename127)
f.close()

# %%
#limpas
f = open('labels_test.txt', 'w')

for a in range(1,81):
    filename = "academia" + str(a) + ".wav ACADEMIA\n"
    f.write(filename)
for l in range(1,81):
    filename15 = "aeroporto" + str(l) + ".wav AEROPORTO\n"
    f.write(filename15)
for v in range(1,81):
    filename29 = "casa" + str(v) + ".wav CASA\n"
    f.write(filename29)    
for ag in range(1,81):
    filename43 = "cinema" + str(ag) + ".wav CINEMA\n"
    f.write(filename43)
for aq in range(1,81):
    filename57 = "escola" + str(aq) + ".wav ESCOLA\n"
    f.write(filename57)
for aac in range(1,81):
    filename71 = "faculdade" + str(aac) + ".wav FACULDADE\n"
    f.write(filename71)
for aam in range(1,81):
    filename85 = "farmacia" + str(aam) + ".wav FARMACIA\n"
    f.write(filename85)
for aaw in range(1,81):
    filename99 = "hospital" + str(aaw) + ".wav HOSPITAL\n"
    f.write(filename99)
for aaah in range(1,81):
    filename113 = "mercado" + str(aaah) + ".wav MERCADO\n"
    f.write(filename113)
for aaar in range(1,81):
    filename127 = "trabalho" + str(aaar) + ".wav TRABALHO\n"
    f.write(filename127)
f.close()
